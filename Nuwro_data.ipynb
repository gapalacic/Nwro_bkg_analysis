# %%
import ROOT
import numpy as np
from ROOT import TCanvas, TH1F, TROOT, TFile, TCanvas
# Out:
# Welcome to JupyROOT 6.16/00

# %%
#%jsroot on 
c = ROOT.TCanvas("myCanvasName","The Canvas Title",800,600)

# %% [markdown]
# Reading the output from Nuwro.

# %%
f = ROOT.TFile("input/ccqedunefinal.root")
# Out:
# Warning in <TClass::Init>: no dictionary for class event is available
# Warning in <TClass::Init>: no dictionary for class flags is available
# Warning in <TClass::Init>: no dictionary for class params is available
# Warning in <TClass::Init>: no dictionary for class line is available
# Warning in <TClass::Init>: no dictionary for class vec is available
# Warning in <TClass::Init>: no dictionary for class particle is available
# Warning in <TClass::Init>: no dictionary for class vect is available

# %% [markdown]
# ## The cross section(s) is(are):

# %%
g=f.xsections

# %%
g.Draw()
c.Draw()

# %% [markdown]
# The events after the interaction in the ND reads

# %%
#tree = f.Get("treeout;4")

# %%
f=TFile("input/ccqedunefinal.root")
tree=f.Get("treeout;3")
tree.Draw("out.t","","goff")
#arr=tree.GetV1()
# Out:
# 155658L

# %%
tree.Draw("out.t")
#tree.Draw("out.t")
#c.SetLogx()
#c.SetLogy()
#c.SetFillColor(2)
c.Draw()

# %% [markdown]
# ### $P_z$ of outgoing lepton

# %%
#tree.Draw("out.t[0].p().z")
tree.Draw("out.t[0].E()")
c.Draw()

# %% [markdown]
# ### Energy of the incoming $\nu_{\mu}$ neutrino

# %%
tree.Draw("in.t[0].E()")
c.Draw()

# %% [markdown]
# ### Primary nucleon kinetic energy

# %%
tree.Draw("in.t[1].Ek()")
c.Draw()

# %%
tree.Draw("out.t[0].p().z/out.t[0].momentum()")
c.Draw()

# %%
tree.Draw("post.t[0].p().z/post.t[0].p().x", "post.pdg == 211")
c.Draw()

# %%
w1=f.Get("out.t")

# %% [markdown]
# ## Listing all the content of the root file

# %%
f.ls()
# Out:
# TFile**		input/ccqedunefinal.root
#  TFile*		input/ccqedunefinal.root
#   OBJ: TTree	treeout	Tree of events : 0 at: 0x689c4e0
#   KEY: TNamed	NuWro version;1	nuwro_19.02.2-26-g3b63c69
#   KEY: TTree	treeout;4	Tree of events
#   KEY: TTree	treeout;3	Tree of events
#   KEY: TH1D	xsections;1	xsections

# %% [markdown]
# ## Choosing a TTree for analysis

# %%
#t = f.Get("treeout;4")
t = f.Get("treeout;4")

# %% [markdown]
# ## Reading data in Trees and Leafs and filling histogram for data analysis

# %%
hist = ROOT.TH1F("myCanvasName","The Canvas Title",800,0,700)

# %%
a=t.GetBranch("out.t")
a.GetEvent()
# Out:
# 20

# %%
a.GetEntry()
# Out:
# 16

# %%
nevent = a.GetEntries()
nselected = 0
for i in range (0,nevent):
    print a.GetEvent(i), a.GetBranchCount()
#for (Int_t  i=0;i<nevent;i++) {
#       GetEvent(i);
#      if (event->GetNtrack() > 587)continue;
#      nselected++;
# Out:
# 16 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# 20 Name: out Title: out_
# ...

# %%
t.GetUniqueID()
# Out:
# 0L

# %%
t.GetEvent(5000)
# Out:
# 3403

# %%
   TBranch  *bntrack  = T.GetBranch ("fNtrack");
   TBranch  *branch   = T.GetBranch ("event");
   branch->SetAddress(&event);
   Int_t  nevent = T.GetEntries();
   Int_t  nselected = 0;
   for (Int_t  i=0;i<nevent;i++) {
      bntrack->GetEvent(i);
      if (event->GetNtrack() > 587)continue;
      nselected++;
      T.GetEvent(i);        //read complete accepted event  in memory
      hnseg->Fill(event->GetNseg());  
            //Fill histogram with number of segments
      tracks  = event->GetTracks();    
            //get pointer to the TClonesArray  object
      tracks->Clear();                //clear it
# Out:
# 100000L

# %%
#tree.Draw("out.t[0].p().z")
for i in tree.GetBranch("out.t[0].p().z"):
    print i
#tree.Draw("out.t[0].E()")
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-34-4b0150a8dfe7> in <module>()
#       1 #tree.Draw("out.t[0].p().z")
# ----> 2 for i in tree.GetBranch("out.t[0].p().z"):
#       3     print i
#       4 #tree.Draw("out.t[0].E()")
#
# TypeError: 'TBranch' object is not iterable

# %% [markdown]
# Analysis

# %%
import ROOT
File = ROOT.TFile("input/ccqedunefinal.root")
Tree = File.Get("treeout;3")
#tree=f.Get("treeout;3")
#tree.Draw("out.t","","goff")
# Out:
# Welcome to JupyROOT 6.16/00

# %%
#Tree.Show(0)

# %%
for event in File.treeout:
    print event.pr

# %%
#Tree.Show(0)
for event in Tree:
    print event.Show()
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...

# %%
hist = ROOT.TH1F("myCanvasName","The Canvas Title",800,0,1000)

# %%
tree.GetEntries()
tree.GetEvent()
# Out:
# 3403

# %%
n_events=tree.GetEntries()
for i in range (0,n_events):
    print tree.GetEvent(i), tree.
# Out:
# 3403
# 3617
# 3403
# 3403
# 3403
# 3617
# 3403
# 3403
# 3831
# 3403
# 3510
# 3510
# 3403
# 3403
# 3510
# 3617
# 3724
# 3403
# 3403
# 3403
# 3403
# 3403
# 3403
# 3510
# 3617
# 3617
# 3403
# 3403
# 3403
# 3403
# 3403
# 3403
# 3831
# 3403
# 3403
# 3403
# 3510
# 3403
# 3510
# 3510
# 3403
# 3403
# 3403
# 3510
# 3403
# 3510
# 3403
# 3403
# 3403
# 3403
# 3403
# 4152
# 3403
# 3403
# 3510
# 3403
# 3510
# 3403
# 3403
# 3403
# 3510
# 3403
# 3403
# 3403
# 3403
# 3403
# 3403
# 3403
# 3403
# 3403
# 3510
# 3510
# 3403
# 3403
# 3403
# 4152
# 3403
# 3510
# 3510
# 3617
# 3403
# 3403
# 3403
# 3617
# 3403
# 4152
# 3510
# 3403
# 3510
# 3403
# 3403
# 3617
# 3724
# 3510
# 3617
# 3403
# 3403
# 3403
# 3403
# 3403
# 3831
# 3403
# 3510
# 3403
# 3403
# 3403
# 3724
# 3403
# 3403
# 3403
# 3403
# 3510
# 3510
# 3403
# 3831
# 3403
# 3617
# 3510
# 3724
# 3510
# 3724
# 3403
# 3403
# 3403
# 3403
# 3403
# 3403
# 3510
# 3403
# 3510
# 3403
# 3724
# 3403
# 3403
# 3403
# 3510
# 3617
# 3510
# 3510
# 3403
# 3617
# 3617
# ...

# %%
tree.ls()
# Out:
# OBJ: TTree	treeout	Tree of events : 0 at: 0x7192080
